# %%
#Use the pandas '.read_csv()' method to assign the contents of the Spotify dataset to a variable
#called songs

import pandas as pd 

#assign the spotify path to a variable
spotify_file="./data/spotify.csv"

#assign the contents of the Spotify dataset to a variable called songs
songs=pd.read_csv(spotify_file,header=0)

#Use 'head()' to show the first five rows of 'songs'
songs.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
#Convert the values in the 'duration_ms' column from strings to integers
import numpy as np 
songs=pd.read_csv(spotify_file,header=0,dtype={'duration_ms':int})

print(songs.dtypes)
# Out:
# Unnamed: 0            int64
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %%
#Convert the values in the 'duration_ms' column from milliseconds to minutes by 
#dividing each value by 60000

def change_duration (duration):
    converted = duration/60000
    return converted

# run the function to update the values in the duration_ms column
songs["duration_ms"]=songs["duration_ms"].map(change_duration)

songs.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73     3.844433     False
# 1            Ghost - Acoustic          55     2.493500     False
# 2              To Begin Again          57     3.513767     False
# ...

# %%
#use 'rename()' to change the name of the 'duration_ms' column to 'minutes_long'
songs=songs.rename(columns={'duration_ms':'minutes_long'})

songs.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  minutes_long  explicit  \
# 0                      Comedy          73      3.844433     False
# 1            Ghost - Acoustic          55      2.493500     False
# 2              To Begin Again          57      3.513767     False
# ...

# %%
#Use '.count()' to show how many times 'FKA twigs' is a value in the 'artists' column
twigs_count=songs[songs.artists=='FKA twigs']
print(twigs_count.count())
# Out:
# Unnamed: 0          50
# track_id            50
# artists             50
# album_name          50
# track_name          50
# popularity          50
# minutes_long        50
# explicit            50
# danceability        50
# energy              50
# key                 50
# loudness            50
# mode                50
# speechiness         50
# acousticness        50
# instrumentalness    50
# liveness            50
# valence             50
# tempo               50
# time_signature      50
# track_genre         50
# dtype: int64

# %%
#Use 'groupby()' to get the max 'danceability' rating for each 'track_genre'ArithmeticError

max_danceability = songs.groupby('track_genre').danceability.max()

print(max_danceability)
# Out:
# track_genre
# acoustic       0.879
# afrobeat       0.974
# alt-rock       0.922
# alternative    0.969
# ambient        0.853
#                ...
# techno         0.952
# trance         0.899
# trip-hop       0.985
# turkish        0.966
# world-music    0.838
# Name: danceability, Length: 114, dtype: float64

# %%
#Use 'shape' to show the number of rows and columns of 'songs'
songs.shape
# Out:
# (114000, 21)

# %%
#Drop the 'valence', 'tempo', and 'time_signature' columns
songs.drop(columns=['valence','tempo','time_signature'],inplace=True)

# %%
#Use 'shape' again to confirm that there are now three fewer columns
songs.shape
# Out:
# (114000, 18)
